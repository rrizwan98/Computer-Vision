# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('parrot1.jpg',1)
img1=img.copy()
px=img1[60,60]
print(px)
# Out:
# [232 220 232]

# %%
img1[60,60]=0

# %%
px=img1[180:184,180:184]#y,x or row, col
print(px)
# Out:
# [[[13 36 44]
#   [12 33 41]
#   [ 8 28 39]
#   [18 38 49]]
#
#  [[16 37 45]
#   [15 36 44]
#   [15 33 44]
#   [25 43 54]]
#
#  [[ 8 29 37]
#   [ 8 29 37]
#   [ 4 25 33]
#   [11 32 40]]
#
#  [[ 8 31 39]
#   [ 9 30 38]
#   [ 2 23 31]
#   [ 5 26 34]]]

# %%
img2=img.copy()
img2[300:400,300:400]=0
plt.imshow(img2[...,::-1])

# %% [markdown]
# ### Task#1 The parrot face axis drow a blue box

# %%
img3=img.copy()
img3[156:244,480:585]=[255,0,0]
plt.imshow(img3[...,::-1])

# %%
img4=img.copy()
rows,cols,channels = img4.shape

# %%
img4[rows//2:rows,0:cols] = [0,0,255] # Colors are in this order blue,gr 
plt.imshow(img4[...,::-1])

# %% [markdown]
# ### Assignment: We have made the bottom horizontal half red now you should Make the the right vertical half of the image blue

# %%
img5=img.copy()

img5[cols//1000:cols,500:cols] = [255,0,0] # Colors are in this order blue,gr 
plt.imshow(img5[...,::-1])

# %%
# Image Properties

print('The shape of the Image is: {}'.format(img.shape))

print('The size of the Image is: {} You can get this value by doing cols * rows * channel')
print('The data type of the Image is: {}'.format(img.dtype))
print('The dimensions of the Image is: {}'.format(img.ndim))
# Out:
# The shape of the Image is: (768, 1024, 3)
# The size of the Image is: {} You can get this value by doing cols * rows * channel
# The data type of the Image is: uint8
# The dimensions of the Image is: 3

# %%
img6=img.copy()
blue=img6[100,100,0]# 0 stand for blue(bgr)
print('The intensity of blue at this location is: {}'.format(blue))
# Out:
# The intensity of blue at this location is: 231

# %%
b,g,r=cv2.split(img6)
plt.figure(figsize=[15,15])

plt.subplot(131);plt.imshow(b,cmap='gray');plt.title('Blue Channel')
plt.subplot(132);plt.imshow(g,cmap='gray');plt.title('Green Channel')
plt.subplot(133);plt.imshow(r,cmap='gray');plt.title('Red Channel')
# Out:
# Text(0.5, 1.0, 'Red Channel')

# %%
img7=img.copy()
img8=img.copy()
img9=img.copy()

img7[:,:,0]=0
img8[:,:,1]=0
img9[:,:,2]=0

plt.figure(figsize=[15,15])
plt.subplot(221);plt.imshow(img[:,:,::-1]);plt.title("Original Image");
plt.subplot(222);plt.imshow(img7[:,:,::-1]);plt.title("Blue Channel Absent");
plt.subplot(223);plt.imshow(img8[:,:,::-1]);plt.title("Green Channel Absent");
plt.subplot(224);plt.imshow(img9[:,:,::-1]);plt.title("Red Channel Absent");

# %% [markdown]
# ### Assignment: Make blue and green channel absent in a single line of code

# %%
img7[:,:,[0,1]]=0



plt.figure(figsize=[15,15])
plt.subplot(221);plt.imshow(img[:,:,::-1]);plt.title("Original Image");
plt.subplot(222);plt.imshow(img7[:,:,::-1]);plt.title("Blue & Green Channel Absent");

# %%
m= cv2.imread('massi.jpg',1)
# %matplotlib notebook
plt.imshow(m)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
original = m.copy()

ball= m[146:175,168:195].copy()
grass = m[146:175, 100:147].copy()

#m[146:175, 100:147] = ball
#m[146:175,168:195] = grass

# %matplotlib inline
plt.figure(figsize=[15,15])
plt.subplot(221);plt.imshow(original[:,:,::-1]);plt.title("Original Image");
plt.subplot(222);plt.imshow(ball[:,:,::-1]);plt.title("Ball");
plt.subplot(223);plt.imshow(grass[:,:,::-1]);plt.title("Grass");
plt.subplot(224);plt.imshow(m[:,:,::-1]);plt.title("ROI");
